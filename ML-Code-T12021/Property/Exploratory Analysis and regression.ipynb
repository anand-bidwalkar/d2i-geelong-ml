# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#import Data
Data = pd.read_csv('cleaning_data.csv')
Data.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-d3274e8a37bb> in <module>
#       4 import matplotlib.pyplot as plt
#       5 #import Data
# ----> 6 Data = pd.read_csv('cleaning_data.csv')
#       7 Data.head(5)
#
# ...

# %%
Data.info()
Data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7704 entries, 0 to 7703
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Suburb             7704 non-null   object
#  1   Suburb_Code        7704 non-null   float64
#  2   Land Size SQM      7704 non-null   float64
#  3   Building Size SQM  7704 non-null   float64
#  4   Bedrooms           7704 non-null   float64
#  5   Toilets            7704 non-null   float64
#  6   Car                7704 non-null   float64
#  7   Rent Date          7704 non-null   object
#  8   Rent Amount PW     7704 non-null   float64
#  9   Auction            7704 non-null   float64
#  10  Last Sell Date     7704 non-null   object
#  11  Last Sell Price    7704 non-null   float64
#  12  Sell Date          7704 non-null   object
#  13  Sell Price         7704 non-null   float64
# dtypes: float64(10), object(4)
# memory usage: 842.8+ KB
# ...

# %%
#Visualize house price
fig = plt.figure(figsize=(10,7))
fig.add_subplot(2,1,1)
sns.distplot(Data['Sell Price'])
fig.add_subplot(2,1,2)
sns.boxplot(Data['Sell Price'])
plt.tight_layout()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#visualizing bedrooms,bathrooms,car space
fig = plt.figure(figsize=(15,7))
fig.add_subplot(2,2,1)
sns.countplot(Data['Bedrooms'])
fig.add_subplot(2,2,2)
sns.countplot(Data['Toilets'])
fig.add_subplot(2,2,4)
sns.countplot(Data['Car'])
plt.tight_layout()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig = plt.figure(figsize=(16,5))
fig.add_subplot(2,2,1)
sns.scatterplot(Data['Land Size SQM'], Data['Sell Price'])
fig.add_subplot(2,2,2)
sns.scatterplot(Data['Building Size SQM'],Data['Sell Price'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Building Size SQM', ylabel='Sell Price'>

# %%
Data['date'] = pd.to_datetime(Data['Sell Date'])
Data['month'] = Data['date'].apply(lambda date:date.month)
Data['year'] = Data['date'].apply(lambda date:date.year)

# %%
#data visualization house price vs months and years
fig = plt.figure(figsize=(16,5))
fig.add_subplot(1,2,1)
Data.groupby('month').mean()['Sell Price'].plot()
fig.add_subplot(1,2,2)
Data.groupby('year').mean()['Sell Price'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
Data['year'].head()
# Out:
# 0    2021
# 1    2021
# 2    2021
# 3    2021
# 4    2021
# Name: year, dtype: int64

# %%
fig = plt.figure(figsize=(16,5))
fig.add_subplot(2,2,1)
Data.groupby('Suburb').mean()['Sell Price'].plot()
# Out:
# <AxesSubplot:xlabel='Suburb'>

# %%
df =Data.groupby('Suburb').mean()['Sell Price']

df.plot.bar()
# Out:
# <AxesSubplot:xlabel='Suburb'>

# %%
Data.isnull().sum()
# Out:
# Suburb               0
# Suburb_Code          0
# Land Size SQM        0
# Building Size SQM    0
# Bedrooms             0
# Toilets              0
# Car                  0
# Rent Date            0
# Rent Amount PW       0
# Auction              0
# Last Sell Date       0
# Last Sell Price      0
# Sell Date            0
# Sell Price           0
# date                 0
# month                0
# year                 0
# dtype: int64

# %%
Data=Data.drop('Suburb',axis=1)
Data=Data.drop('Rent Date',axis=1)
Data=Data.drop('date',axis=1)
Data=Data.drop('Last Sell Date',axis=1)
Data=Data.drop('Sell Date',axis=1)

# %%
Data.dtypes
# Out:
# Suburb_Code          float64
# Land Size SQM        float64
# Building Size SQM    float64
# Bedrooms             float64
# Toilets              float64
# Car                  float64
# Rent Amount PW       float64
# Auction              float64
# Last Sell Price      float64
# Sell Price           float64
# month                  int64
# year                   int64
# dtype: object

# %%
x=Data.drop('Sell Price',axis=1).values
y=Data['Sell Price'].values
print(x)
# Out:
# [[1.00000000e+00 5.39000000e+02 1.76000000e+02 ... 1.75000000e+05
#   3.00000000e+00 2.02100000e+03]
#  [1.00000000e+00 4.46000000e+02 1.72849734e+02 ... 5.45000000e+05
#   3.00000000e+00 2.02100000e+03]
#  [1.00000000e+00 3.98000000e+02 1.61000000e+02 ... 5.50000000e+05
#   3.00000000e+00 2.02100000e+03]
#  ...
#  [3.10000000e+01 6.45000000e+02 1.22000000e+02 ... 1.78000000e+05
#   6.00000000e+00 2.01600000e+03]
#  [3.10000000e+01 7.74000000e+02 1.72849734e+02 ... 1.43000000e+05
#   6.00000000e+00 2.01600000e+03]
#  [3.10000000e+01 5.82000000e+02 1.26000000e+02 ... 2.06500000e+05
#   6.00000000e+00 2.01600000e+03]]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler
s_scaler = StandardScaler()
x_train = s_scaler.fit_transform(x_train.astype(np.float))
x_test = s_scaler.transform(x_test.astype(np.float))

# %%
# !pip install tensorflow
# Out:
# ...
#   Created wheel for wrapt: filename=wrapt-1.12.1-py3-none-any.whl size=19558 sha256=64632deaa8e5299fcffe092c363097b5f5f649d09d53c3c2305ab6dc91441abd
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\5f\fd\9e\b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4835 sha256=38dd63cc4a3afb8b3a735676361ca1390dccac7ea543c871fabc32e5345ccb23
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# Successfully built wrapt termcolor
# ...
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.11.2
#     Uninstalling wrapt-1.11.2:
#       Successfully uninstalled wrapt-1.11.2
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()
model.add(Dense(11,activation='relu'))
model.add(Dense(11,activation='relu'))
model.add(Dense(11,activation='relu'))
model.add(Dense(11,activation='relu'))
model.add(Dense(1))
model.compile(optimizer='Adam',loss='categorical_crossentropy')

# %%
model.fit(x=x_train,y=y_train,
          validation_data=(x_test,y_test),
          batch_size=200,epochs=400)
model.summary()
# Out:
# Epoch 1/400
# 26/26 [==============================] - 3s 34ms/step - loss: 0.0688 - val_loss: 0.0671
# Epoch 2/400
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0681 - val_loss: 0.0671
# Epoch 3/400
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0679 - val_loss: 0.0671
# Epoch 4/400
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0687 - val_loss: 0.0671
# Epoch 5/400
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0683 - val_loss: 0.0671
# Epoch 6/400
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0700 - val_loss: 0.0671
# Epoch 7/400
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0685 - val_loss: 0.0671
# Epoch 8/400
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0672 - val_loss: 0.0671
# Epoch 9/400
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0681 - val_loss: 0.0671
# Epoch 10/400
# ...

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
y_pred = model.predict(x_test)
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))  
print('MSE:', metrics.mean_squared_error(y_test, y_pred))  
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('VarScore:',metrics.explained_variance_score(y_test,y_pred))
# Visualizing Our predictions
fig = plt.figure(figsize=(10,5))
plt.scatter(y_test,y_pred)
# Perfect predictions
plt.plot(y_test,y_test,'r')
# Out:
# MAE: 562767.3820121757
# MSE: 433706117131.41034
# RMSE: 658563.677355053
# VarScore: -1.1654907505764811e-07

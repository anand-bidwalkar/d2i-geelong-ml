# %%
import pandas as pd
pd_df = pd.read_csv('Parking_data_final.csv')
print(pd_df)
# Out:
#        Unnamed: 0  ...                                            address
# 0               0  ...  Officeworks, 150, Malop Street, Geelong, City ...
# 1               1  ...  Officeworks, 150, Malop Street, Geelong, City ...
# 2               2  ...  Yarra Street, Geelong, City of Greater Geelong...
# 3               3  ...  Yarra Street, Geelong, City of Greater Geelong...
# 4               4  ...  Yarra Street, Geelong, City of Greater Geelong...
# ...           ...  ...                                                ...
# 41974       79951  ...  159,161, Malop Street, Geelong, City of Greate...
# 41975       79952  ...  159,161, Malop Street, Geelong, City of Greate...
# 41976       79953  ...  159,161, Malop Street, Geelong, City of Greate...
# 41977       79954  ...  159,161, Malop Street, Geelong, City of Greate...
# 41978       79955  ...  159,161, Malop Street, Geelong, City of Greate...
#
# [41979 rows x 15 columns]

# %%
pd_df = pd.DataFrame(pd_df)

# %%
pd_df.hist(figsize=(25, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efcbd726048>,
# ...
#       dtype=object)

# %%
pd_df_final = pd_df.iloc[:,2:]
pd_df_final = pd_df_final.drop('frame_type', axis = 1)
print(pd_df_final)
pd_df_final.corr()
# Out:
#          deviceName  ...                                            address
# 0      Parking_2532  ...  Officeworks, 150, Malop Street, Geelong, City ...
# 1      Parking_2532  ...  Officeworks, 150, Malop Street, Geelong, City ...
# 2      Parking_2535  ...  Yarra Street, Geelong, City of Greater Geelong...
# 3      Parking_2535  ...  Yarra Street, Geelong, City of Greater Geelong...
# 4      Parking_2535  ...  Yarra Street, Geelong, City of Greater Geelong...
# ...             ...  ...                                                ...
# 41974  Parking_2667  ...  159,161, Malop Street, Geelong, City of Greate...
# 41975  Parking_2667  ...  159,161, Malop Street, Geelong, City of Greate...
# 41976  Parking_2667  ...  159,161, Malop Street, Geelong, City of Greate...
# 41977  Parking_2667  ...  159,161, Malop Street, Geelong, City of Greate...
# 41978  Parking_2667  ...  159,161, Malop Street, Geelong, City of Greate...
#
# [41979 rows x 12 columns]
# ...

# %%
import seaborn as sns
sns.heatmap(pd_df_final.corr())

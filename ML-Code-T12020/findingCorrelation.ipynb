# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('geelongbuiltenv.csv')

# %%
dataset.head()
# Out:
#                     Suburb  ...  RatioTrailsToRoadsquintile
# 0        10Clifton Springs  ...                           2
# 1           11Geelong West  ...                           1
# 2         12Newcomb/Moolap  ...                           3
# 3  13City/Drum/Sth Geelong  ...                           3
# 4         14Hamlyn Heights  ...                           3
#
# [5 rows x 39 columns]

# %%
dataset.describe(include='all')
# Out:
#                     Suburb  ...  RatioTrailsToRoadsquintile
# count                   46  ...                   46.000000
# unique                  46  ...                         NaN
# top     29Manifold Heights  ...                         NaN
# freq                     1  ...                         NaN
# mean                   NaN  ...                    3.000000
# std                    NaN  ...                    1.445299
# min                    NaN  ...                    1.000000
# 25%                    NaN  ...                    2.000000
# 50%                    NaN  ...                    3.000000
# 75%                    NaN  ...                    4.000000
# max                    NaN  ...                    5.000000
#
# [11 rows x 39 columns]

# %%
fig, ax = plt.subplots(figsize=(20,20))

sb.heatmap(dataset.corr(),annot=True,fmt='.1g',cmap='coolwarm',linewidths=.5,ax=ax)

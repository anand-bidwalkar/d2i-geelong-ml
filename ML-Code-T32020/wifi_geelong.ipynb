# %%
import pandas as pd

wfwg = pd.read_csv("wifi_weather_geelong_2019.csv")

wfwg
# Out:
#        Unnamed: 0        date  ... 3pm_ws  3pm_mslp
# 0               0  2019-01-01  ...     20    1012.4
# 1               1  2019-01-01  ...     20    1012.4
# 2               2  2019-01-01  ...     20    1012.4
# 3               3  2019-01-01  ...     20    1012.4
# 4               4  2019-01-01  ...     20    1012.4
# ...           ...         ...  ...    ...       ...
# 48659       48659  2019-12-31  ...     26    1012.6
# 48660       48660  2019-12-31  ...     26    1012.6
# 48661       48661  2019-12-31  ...     26    1012.6
# 48662       48662  2019-12-31  ...     26    1012.6
# 48663       48663  2019-12-31  ...     26    1012.6
#
# [48664 rows x 27 columns]

# %%
wfwg.notnull()
# Out:
#        Unnamed: 0  date  location  hour  ...  3pm_rh  3pm_wd  3pm_ws  3pm_mslp
# 0            True  True      True  True  ...    True    True    True      True
# 1            True  True      True  True  ...    True    True    True      True
# 2            True  True      True  True  ...    True    True    True      True
# 3            True  True      True  True  ...    True    True    True      True
# 4            True  True      True  True  ...    True    True    True      True
# ...           ...   ...       ...   ...  ...     ...     ...     ...       ...
# 48659        True  True      True  True  ...    True    True    True      True
# 48660        True  True      True  True  ...    True    True    True      True
# 48661        True  True      True  True  ...    True    True    True      True
# 48662        True  True      True  True  ...    True    True    True      True
# 48663        True  True      True  True  ...    True    True    True      True
#
# ...

# %%
wfwg.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe005741e10>,
# ...
#       dtype=object)

# %%
wfwg.corr()
# Out:
#              Unnamed: 0      hour      left  ...    3pm_rh    3pm_ws  3pm_mslp
# Unnamed: 0     1.000000 -0.003623  0.132192  ... -0.133795  0.272221 -0.221881
# hour          -0.003623  1.000000  0.126417  ... -0.001153  0.001466 -0.003190
# left           0.132192  0.126417  1.000000  ... -0.005371  0.042361 -0.037180
# left_avg      -0.179712  0.067981  0.001901  ...  0.023488 -0.050206  0.054209
# total          0.102006  0.120809  0.985670  ...  0.002663  0.034333 -0.028057
# year                NaN       NaN       NaN  ...       NaN       NaN       NaN
# month          0.961033 -0.002141  0.129139  ... -0.130029  0.284972 -0.268950
# day            0.178910  0.000911  0.005572  ... -0.113443  0.048644 -0.059666
# dayofweek     -0.006853  0.000539  0.009486  ...  0.095680 -0.038131  0.069490
# mintemp        0.060145  0.005459  0.005190  ... -0.150228  0.169479 -0.256022
# maxtemp        0.149340  0.004115  0.004848  ... -0.713936  0.041982 -0.429540
# ...

# %%
wfwg.rainfall.hist()

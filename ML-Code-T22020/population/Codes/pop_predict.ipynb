# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import re
import json
import warnings
warnings.filterwarnings("ignore")
file_name='totalgeelong2.csv'
df = pd.read_csv(file_name)
df.head(17)
# Out:
#     Year     City  Population
# 0   2003  Geelong      162637
# 1   2004  Geelong      164134
# 2   2005  Geelong      165827
# 3   2006  Geelong      137222
# 4   2007  Geelong      169544
# 5   2008  Geelong      172300
# 6   2009  Geelong      175803
# 7   2010  Geelong      178650
# 8   2011  Geelong      177023
# 9   2012  Geelong      179689
# 10  2013  Geelong      181853
# 11  2014  Geelong      184182
# 12  2015  Geelong      187417
# 13  2016  Geelong      253269
# 14  2017  Geelong      245751
# 15  2018  Geelong      252217

# %%
x = df.iloc[0:16, 0].values.reshape(-1, 1)
y = df.iloc[0:16, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2021]])

y_pred
# Out:
# array([[248154.13970588]])

# %%
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Bell Park',"Year" : i,"Population" : y_pred}, ignore_index = True)
# Out:
# 2020 =[[5418.71428571]]
# 2021 =[[5477.01190476]]
# 2022 =[[5535.30952381]]
# 2023 =[[5593.60714286]]
# 2024 =[[5651.9047619]]
# 2025 =[[5710.20238095]]
# 2026 =[[5768.5]]
# 2027 =[[5826.79761905]]
# 2028 =[[5885.0952381]]
# 2029 =[[5943.39285714]]
# 2030 =[[6001.69047619]]
# 2031 =[[6059.98809524]]
# 2032 =[[6118.28571429]]
# 2033 =[[6176.58333333]]
# 2034 =[[6234.88095238]]
# 2035 =[[6293.17857143]]
# 2036 =[[6351.47619048]]
# 2037 =[[6409.77380952]]
# 2038 =[[6468.07142857]]
# 2039 =[[6526.36904762]]
# 2040 =[[6584.66666667]]
# 2041 =[[6642.96428571]]
# 2042 =[[6701.26190476]]
# 2043 =[[6759.55952381]]
# 2044 =[[6817.85714286]]
# 2045 =[[6876.1547619]]
# 2046 =[[6934.45238095]]
# 2047 =[[6992.75]]
# 2048 =[[7051.04761905]]
# 2049 =[[7109.3452381]]

# %%
# df.head(20)
df.to_csv('bellpark_predict.csv')

# %%
import matplotlib.pyplot as plt
df_predict=pd.read_csv('bellpark_predict.csv')
x = df_predict.iloc[:, 1]
y = df_predict.iloc[:, 3]
plt.plot(x, y, 'o')



m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-51a70feefc35> in <module>
#       7
#       8
# ----> 9 m, b = np.polyfit(x, y, 1)
#      10 plt.plot(x, m*x + b)
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     590     """
#     591     order = int(deg) + 1
# --> 592     x = NX.asarray(x) + 0.0
#     593     y = NX.asarray(y) + 0.0
#     594
#
# TypeError: can only concatenate str (not "float") to str

# %%
df = pd.read_csv('Bell Post Hill.csv')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Bell Post Hill',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('bellposthill_predict.csv')
# Out:
# 2020 =[[5174.35714286]]
# 2021 =[[5195.63095238]]
# 2022 =[[5216.9047619]]
# 2023 =[[5238.17857143]]
# 2024 =[[5259.45238095]]
# 2025 =[[5280.72619048]]
# 2026 =[[5302.]]
# 2027 =[[5323.27380952]]
# 2028 =[[5344.54761905]]
# 2029 =[[5365.82142857]]
# 2030 =[[5387.0952381]]
# 2031 =[[5408.36904762]]
# 2032 =[[5429.64285714]]
# 2033 =[[5450.91666667]]
# 2034 =[[5472.19047619]]
# 2035 =[[5493.46428571]]
# 2036 =[[5514.73809524]]
# 2037 =[[5536.01190476]]
# 2038 =[[5557.28571429]]
# 2039 =[[5578.55952381]]
# 2040 =[[5599.83333333]]
# 2041 =[[5621.10714286]]
# 2042 =[[5642.38095238]]
# 2043 =[[5663.6547619]]
# 2044 =[[5684.92857143]]
# 2045 =[[5706.20238095]]
# 2046 =[[5727.47619048]]
# 2047 =[[5748.75]]
# 2048 =[[5770.02380952]]
# 2049 =[[5791.29761905]]

# %%
df = pd.read_csv('Belmont.csv')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Belmont',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('belmont_predict.csv')
# Out:
# 2020 =[[14885.57142857]]
# 2021 =[[15009.72619048]]
# 2022 =[[15133.88095238]]
# 2023 =[[15258.03571429]]
# 2024 =[[15382.19047619]]
# 2025 =[[15506.3452381]]
# 2026 =[[15630.5]]
# 2027 =[[15754.6547619]]
# 2028 =[[15878.80952381]]
# 2029 =[[16002.96428571]]
# 2030 =[[16127.11904762]]
# 2031 =[[16251.27380952]]
# 2032 =[[16375.42857143]]
# 2033 =[[16499.58333333]]
# 2034 =[[16623.73809524]]
# 2035 =[[16747.89285714]]
# 2036 =[[16872.04761905]]
# 2037 =[[16996.20238095]]
# 2038 =[[17120.35714286]]
# 2039 =[[17244.51190476]]
# 2040 =[[17368.66666667]]
# 2041 =[[17492.82142857]]
# 2042 =[[17616.97619048]]
# 2043 =[[17741.13095238]]
# 2044 =[[17865.28571429]]
# 2045 =[[17989.44047619]]
# 2046 =[[18113.5952381]]
# 2047 =[[18237.75]]
# 2048 =[[18361.9047619]]
# 2049 =[[18486.05952381]]

# %%
df = pd.read_csv('Clifton Springs.csv')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Clifton Springs',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('Cliftonsprings_predict.csv')
# Out:
# 2020 =[[7948.42857143]]
# 2021 =[[8012.69047619]]
# 2022 =[[8076.95238095]]
# 2023 =[[8141.21428571]]
# 2024 =[[8205.47619048]]
# 2025 =[[8269.73809524]]
# 2026 =[[8334.]]
# 2027 =[[8398.26190476]]
# 2028 =[[8462.52380952]]
# 2029 =[[8526.78571429]]
# 2030 =[[8591.04761905]]
# 2031 =[[8655.30952381]]
# 2032 =[[8719.57142857]]
# 2033 =[[8783.83333333]]
# 2034 =[[8848.0952381]]
# 2035 =[[8912.35714286]]
# 2036 =[[8976.61904762]]
# 2037 =[[9040.88095238]]
# 2038 =[[9105.14285714]]
# 2039 =[[9169.4047619]]
# 2040 =[[9233.66666667]]
# 2041 =[[9297.92857143]]
# 2042 =[[9362.19047619]]
# 2043 =[[9426.45238095]]
# 2044 =[[9490.71428571]]
# 2045 =[[9554.97619048]]
# 2046 =[[9619.23809524]]
# 2047 =[[9683.5]]
# 2048 =[[9747.76190476]]
# 2049 =[[9812.02380952]]

# %%
df = pd.read_csv('Corio.csv')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Corio',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('Corio_predict.csv')
# Out:
# 2020 =[[16090.92857143]]
# 2021 =[[16173.35714286]]
# 2022 =[[16255.78571429]]
# 2023 =[[16338.21428571]]
# 2024 =[[16420.64285714]]
# 2025 =[[16503.07142857]]
# 2026 =[[16585.5]]
# 2027 =[[16667.92857143]]
# 2028 =[[16750.35714286]]
# 2029 =[[16832.78571429]]
# 2030 =[[16915.21428571]]
# 2031 =[[16997.64285714]]
# 2032 =[[17080.07142857]]
# 2033 =[[17162.5]]
# 2034 =[[17244.92857143]]
# 2035 =[[17327.35714286]]
# 2036 =[[17409.78571429]]
# 2037 =[[17492.21428571]]
# 2038 =[[17574.64285714]]
# 2039 =[[17657.07142857]]
# 2040 =[[17739.5]]
# 2041 =[[17821.92857143]]
# 2042 =[[17904.35714286]]
# 2043 =[[17986.78571429]]
# 2044 =[[18069.21428571]]
# 2045 =[[18151.64285714]]
# 2046 =[[18234.07142857]]
# 2047 =[[18316.5]]
# 2048 =[[18398.92857143]]
# 2049 =[[18481.35714286]]

# %%
df = pd.read_csv('Curlewis.csv')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Curlewis',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('Curlewis_predict.csv')
# Out:
# 2020 =[[2818.39285714]]
# 2021 =[[3119.53571429]]
# 2022 =[[3420.67857143]]
# 2023 =[[3721.82142857]]
# 2024 =[[4022.96428571]]
# 2025 =[[4324.10714286]]
# 2026 =[[4625.25]]
# 2027 =[[4926.39285714]]
# 2028 =[[5227.53571429]]
# 2029 =[[5528.67857143]]
# 2030 =[[5829.82142857]]
# 2031 =[[6130.96428571]]
# 2032 =[[6432.10714286]]
# 2033 =[[6733.25]]
# 2034 =[[7034.39285714]]
# 2035 =[[7335.53571429]]
# 2036 =[[7636.67857143]]
# 2037 =[[7937.82142857]]
# 2038 =[[8238.96428571]]
# 2039 =[[8540.10714286]]
# 2040 =[[8841.25]]
# 2041 =[[9142.39285714]]
# 2042 =[[9443.53571429]]
# 2043 =[[9744.67857143]]
# 2044 =[[10045.82142857]]
# 2045 =[[10346.96428571]]
# 2046 =[[10648.10714286]]
# 2047 =[[10949.25]]
# 2048 =[[11250.39285714]]
# 2049 =[[11551.53571429]]

# %%
df = pd.read_csv('Drysdale.csv')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Drysdale',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('Drysdale_predict.csv')
# Out:
# 2020 =[[5066.67857143]]
# 2021 =[[5198.60714286]]
# 2022 =[[5330.53571429]]
# 2023 =[[5462.46428571]]
# 2024 =[[5594.39285714]]
# 2025 =[[5726.32142857]]
# 2026 =[[5858.25]]
# 2027 =[[5990.17857143]]
# 2028 =[[6122.10714286]]
# 2029 =[[6254.03571429]]
# 2030 =[[6385.96428571]]
# 2031 =[[6517.89285714]]
# 2032 =[[6649.82142857]]
# 2033 =[[6781.75]]
# 2034 =[[6913.67857143]]
# 2035 =[[7045.60714286]]
# 2036 =[[7177.53571429]]
# 2037 =[[7309.46428571]]
# 2038 =[[7441.39285714]]
# 2039 =[[7573.32142857]]
# 2040 =[[7705.25]]
# 2041 =[[7837.17857143]]
# 2042 =[[7969.10714286]]
# 2043 =[[8101.03571429]]
# 2044 =[[8232.96428571]]
# 2045 =[[8364.89285714]]
# 2046 =[[8496.82142857]]
# 2047 =[[8628.75]]
# 2048 =[[8760.67857143]]
# 2049 =[[8892.60714286]]

# %%
df = pd.read_csv('East Geelong.csv')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'East Geelong',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('eastgeelong_predict.csv')
# Out:
# 2020 =[[4067.71428571]]
# 2021 =[[4085.17857143]]
# 2022 =[[4102.64285714]]
# 2023 =[[4120.10714286]]
# 2024 =[[4137.57142857]]
# 2025 =[[4155.03571429]]
# 2026 =[[4172.5]]
# 2027 =[[4189.96428571]]
# 2028 =[[4207.42857143]]
# 2029 =[[4224.89285714]]
# 2030 =[[4242.35714286]]
# 2031 =[[4259.82142857]]
# 2032 =[[4277.28571429]]
# 2033 =[[4294.75]]
# 2034 =[[4312.21428571]]
# 2035 =[[4329.67857143]]
# 2036 =[[4347.14285714]]
# 2037 =[[4364.60714286]]
# 2038 =[[4382.07142857]]
# 2039 =[[4399.53571429]]
# 2040 =[[4417.]]
# 2041 =[[4434.46428571]]
# 2042 =[[4451.92857143]]
# 2043 =[[4469.39285714]]
# 2044 =[[4486.85714286]]
# 2045 =[[4504.32142857]]
# 2046 =[[4521.78571429]]
# 2047 =[[4539.25]]
# 2048 =[[4556.71428571]]
# 2049 =[[4574.17857143]]

# %%
df = pd.read_csv('Geelong west.csv')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'West Geelong',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('westgeelong_predict.csv')
# Out:
# 2020 =[[10390.75]]
# 2021 =[[10511.33333333]]
# 2022 =[[10631.91666667]]
# 2023 =[[10752.5]]
# 2024 =[[10873.08333333]]
# 2025 =[[10993.66666667]]
# 2026 =[[11114.25]]
# 2027 =[[11234.83333333]]
# 2028 =[[11355.41666667]]
# 2029 =[[11476.]]
# 2030 =[[11596.58333333]]
# 2031 =[[11717.16666667]]
# 2032 =[[11837.75]]
# 2033 =[[11958.33333333]]
# 2034 =[[12078.91666667]]
# 2035 =[[12199.5]]
# 2036 =[[12320.08333333]]
# 2037 =[[12440.66666667]]
# 2038 =[[12561.25]]
# 2039 =[[12681.83333333]]
# 2040 =[[12802.41666667]]
# 2041 =[[12923.]]
# 2042 =[[13043.58333333]]
# 2043 =[[13164.16666667]]
# 2044 =[[13284.75]]
# 2045 =[[13405.33333333]]
# 2046 =[[13525.91666667]]
# 2047 =[[13646.5]]
# 2048 =[[13767.08333333]]
# 2049 =[[13887.66666667]]

# %%
df = pd.read_csv('Grovedale.csv')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Grovedale',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('grovedale_predict.csv')
# Out:
# 2020 =[[15535.32142857]]
# 2021 =[[15764.55952381]]
# 2022 =[[15993.79761905]]
# 2023 =[[16223.03571429]]
# 2024 =[[16452.27380952]]
# 2025 =[[16681.51190476]]
# 2026 =[[16910.75]]
# 2027 =[[17139.98809524]]
# 2028 =[[17369.22619048]]
# 2029 =[[17598.46428571]]
# 2030 =[[17827.70238095]]
# 2031 =[[18056.94047619]]
# 2032 =[[18286.17857143]]
# 2033 =[[18515.41666667]]
# 2034 =[[18744.6547619]]
# 2035 =[[18973.89285714]]
# 2036 =[[19203.13095238]]
# 2037 =[[19432.36904762]]
# 2038 =[[19661.60714286]]
# 2039 =[[19890.8452381]]
# 2040 =[[20120.08333333]]
# 2041 =[[20349.32142857]]
# 2042 =[[20578.55952381]]
# 2043 =[[20807.79761905]]
# 2044 =[[21037.03571429]]
# 2045 =[[21266.27380952]]
# 2046 =[[21495.51190476]]
# 2047 =[[21724.75]]
# 2048 =[[21953.98809524]]
# 2049 =[[22183.22619048]]

# %%
df = pd.read_csv('Hamlyn Heights.csv')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Hamlyn Heights',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('hamlynheights_predict.csv')
# Out:
# 2020 =[[6774.64285714]]
# 2021 =[[6851.28571429]]
# 2022 =[[6927.92857143]]
# 2023 =[[7004.57142857]]
# 2024 =[[7081.21428571]]
# 2025 =[[7157.85714286]]
# 2026 =[[7234.5]]
# 2027 =[[7311.14285714]]
# 2028 =[[7387.78571429]]
# 2029 =[[7464.42857143]]
# 2030 =[[7541.07142857]]
# 2031 =[[7617.71428571]]
# 2032 =[[7694.35714286]]
# 2033 =[[7771.]]
# 2034 =[[7847.64285714]]
# 2035 =[[7924.28571429]]
# 2036 =[[8000.92857143]]
# 2037 =[[8077.57142857]]
# 2038 =[[8154.21428571]]
# 2039 =[[8230.85714286]]
# 2040 =[[8307.5]]
# 2041 =[[8384.14285714]]
# 2042 =[[8460.78571429]]
# 2043 =[[8537.42857143]]
# 2044 =[[8614.07142857]]
# 2045 =[[8690.71428571]]
# 2046 =[[8767.35714286]]
# 2047 =[[8844.]]
# 2048 =[[8920.64285714]]
# 2049 =[[8997.28571429]]

# %%
df = pd.read_csv('Herne Hill.csv')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Herne Hill',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('hernehill_predict.csv')
# Out:
# 2020 =[[3862.78571429]]
# 2021 =[[3898.82142857]]
# 2022 =[[3934.85714286]]
# 2023 =[[3970.89285714]]
# 2024 =[[4006.92857143]]
# 2025 =[[4042.96428571]]
# 2026 =[[4079.]]
# 2027 =[[4115.03571429]]
# 2028 =[[4151.07142857]]
# 2029 =[[4187.10714286]]
# 2030 =[[4223.14285714]]
# 2031 =[[4259.17857143]]
# 2032 =[[4295.21428571]]
# 2033 =[[4331.25]]
# 2034 =[[4367.28571429]]
# 2035 =[[4403.32142857]]
# 2036 =[[4439.35714286]]
# 2037 =[[4475.39285714]]
# 2038 =[[4511.42857143]]
# 2039 =[[4547.46428571]]
# 2040 =[[4583.5]]
# 2041 =[[4619.53571429]]
# 2042 =[[4655.57142857]]
# 2043 =[[4691.60714286]]
# 2044 =[[4727.64285714]]
# 2045 =[[4763.67857143]]
# 2046 =[[4799.71428571]]
# 2047 =[[4835.75]]
# 2048 =[[4871.78571429]]
# 2049 =[[4907.82142857]]

# %%
df = pd.read_csv('Highton.csv')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Highton',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('highton_predict.csv')
# Out:
# 2020 =[[23187.85714286]]
# 2021 =[[23613.13095238]]
# 2022 =[[24038.4047619]]
# 2023 =[[24463.67857143]]
# 2024 =[[24888.95238095]]
# 2025 =[[25314.22619048]]
# 2026 =[[25739.5]]
# 2027 =[[26164.77380952]]
# 2028 =[[26590.04761905]]
# 2029 =[[27015.32142857]]
# 2030 =[[27440.5952381]]
# 2031 =[[27865.86904762]]
# 2032 =[[28291.14285714]]
# 2033 =[[28716.41666667]]
# 2034 =[[29141.69047619]]
# 2035 =[[29566.96428571]]
# 2036 =[[29992.23809524]]
# 2037 =[[30417.51190476]]
# 2038 =[[30842.78571429]]
# 2039 =[[31268.05952381]]
# 2040 =[[31693.33333333]]
# 2041 =[[32118.60714286]]
# 2042 =[[32543.88095238]]
# 2043 =[[32969.1547619]]
# 2044 =[[33394.42857143]]
# 2045 =[[33819.70238095]]
# 2046 =[[34244.97619048]]
# 2047 =[[34670.25]]
# 2048 =[[35095.52380952]]
# 2049 =[[35520.79761905]]

# %%
df = pd.read_csv('Lara.csv')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Lara',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('lara_predict.csv')
# Out:
# 2020 =[[19053.32142857]]
# 2021 =[[19590.30952381]]
# 2022 =[[20127.29761905]]
# 2023 =[[20664.28571429]]
# 2024 =[[21201.27380952]]
# 2025 =[[21738.26190476]]
# 2026 =[[22275.25]]
# 2027 =[[22812.23809524]]
# 2028 =[[23349.22619048]]
# 2029 =[[23886.21428571]]
# 2030 =[[24423.20238095]]
# 2031 =[[24960.19047619]]
# 2032 =[[25497.17857143]]
# 2033 =[[26034.16666667]]
# 2034 =[[26571.1547619]]
# 2035 =[[27108.14285714]]
# 2036 =[[27645.13095238]]
# 2037 =[[28182.11904762]]
# 2038 =[[28719.10714286]]
# 2039 =[[29256.0952381]]
# 2040 =[[29793.08333333]]
# 2041 =[[30330.07142857]]
# 2042 =[[30867.05952381]]
# 2043 =[[31404.04761905]]
# 2044 =[[31941.03571429]]
# 2045 =[[32478.02380952]]
# 2046 =[[33015.01190476]]
# 2047 =[[33552.]]
# 2048 =[[34088.98809524]]
# 2049 =[[34625.97619048]]

# %%
df = pd.read_csv('Leopold.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Leopold',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('leopold_predict.csv')
# Out:
# 2020 =[[14704.28571429]]
# 2021 =[[15176.57142857]]
# 2022 =[[15648.85714286]]
# 2023 =[[16121.14285714]]
# 2024 =[[16593.42857143]]
# 2025 =[[17065.71428571]]
# 2026 =[[17538.]]
# 2027 =[[18010.28571429]]
# 2028 =[[18482.57142857]]
# 2029 =[[18954.85714286]]
# 2030 =[[19427.14285714]]
# 2031 =[[19899.42857143]]
# 2032 =[[20371.71428571]]
# 2033 =[[20844.]]
# 2034 =[[21316.28571429]]
# 2035 =[[21788.57142857]]
# 2036 =[[22260.85714286]]
# 2037 =[[22733.14285714]]
# 2038 =[[23205.42857143]]
# 2039 =[[23677.71428571]]
# 2040 =[[24150.]]
# 2041 =[[24622.28571429]]
# 2042 =[[25094.57142857]]
# 2043 =[[25566.85714286]]
# 2044 =[[26039.14285714]]
# 2045 =[[26511.42857143]]
# 2046 =[[26983.71428571]]
# 2047 =[[27456.]]
# 2048 =[[27928.28571429]]
# 2049 =[[28400.57142857]]

# %%
df = pd.read_csv('Lovely Banks.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Lovely Banks',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('lovelybanks_predict.csv')
# Out:
# 2020 =[[2788.10714286]]
# 2021 =[[2809.46428571]]
# 2022 =[[2830.82142857]]
# 2023 =[[2852.17857143]]
# 2024 =[[2873.53571429]]
# 2025 =[[2894.89285714]]
# 2026 =[[2916.25]]
# 2027 =[[2937.60714286]]
# 2028 =[[2958.96428571]]
# 2029 =[[2980.32142857]]
# 2030 =[[3001.67857143]]
# 2031 =[[3023.03571429]]
# 2032 =[[3044.39285714]]
# 2033 =[[3065.75]]
# 2034 =[[3087.10714286]]
# 2035 =[[3108.46428571]]
# 2036 =[[3129.82142857]]
# 2037 =[[3151.17857143]]
# 2038 =[[3172.53571429]]
# 2039 =[[3193.89285714]]
# 2040 =[[3215.25]]
# 2041 =[[3236.60714286]]
# 2042 =[[3257.96428571]]
# 2043 =[[3279.32142857]]
# 2044 =[[3300.67857143]]
# 2045 =[[3322.03571429]]
# 2046 =[[3343.39285714]]
# 2047 =[[3364.75]]
# 2048 =[[3386.10714286]]
# 2049 =[[3407.46428571]]

# %%
df = pd.read_csv('Marshall.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Marshall',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('Marshall_predict.csv')
# Out:
# 2020 =[[3568.71428571]]
# 2021 =[[3819.92857143]]
# 2022 =[[4071.14285714]]
# 2023 =[[4322.35714286]]
# 2024 =[[4573.57142857]]
# 2025 =[[4824.78571429]]
# 2026 =[[5076.]]
# 2027 =[[5327.21428571]]
# 2028 =[[5578.42857143]]
# 2029 =[[5829.64285714]]
# 2030 =[[6080.85714286]]
# 2031 =[[6332.07142857]]
# 2032 =[[6583.28571429]]
# 2033 =[[6834.5]]
# 2034 =[[7085.71428571]]
# 2035 =[[7336.92857143]]
# 2036 =[[7588.14285714]]
# 2037 =[[7839.35714286]]
# 2038 =[[8090.57142857]]
# 2039 =[[8341.78571429]]
# 2040 =[[8593.]]
# 2041 =[[8844.21428571]]
# 2042 =[[9095.42857143]]
# 2043 =[[9346.64285714]]
# 2044 =[[9597.85714286]]
# 2045 =[[9849.07142857]]
# 2046 =[[10100.28571429]]
# 2047 =[[10351.5]]
# 2048 =[[10602.71428571]]
# 2049 =[[10853.92857143]]

# %%
df = pd.read_csv('Newcomb.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Newcomb',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('newcomb_predict.csv')
# Out:
# 2020 =[[6137.25]]
# 2021 =[[6180.25]]
# 2022 =[[6223.25]]
# 2023 =[[6266.25]]
# 2024 =[[6309.25]]
# 2025 =[[6352.25]]
# 2026 =[[6395.25]]
# 2027 =[[6438.25]]
# 2028 =[[6481.25]]
# 2029 =[[6524.25]]
# 2030 =[[6567.25]]
# 2031 =[[6610.25]]
# 2032 =[[6653.25]]
# 2033 =[[6696.25]]
# 2034 =[[6739.25]]
# 2035 =[[6782.25]]
# 2036 =[[6825.25]]
# 2037 =[[6868.25]]
# 2038 =[[6911.25]]
# 2039 =[[6954.25]]
# 2040 =[[6997.25]]
# 2041 =[[7040.25]]
# 2042 =[[7083.25]]
# 2043 =[[7126.25]]
# 2044 =[[7169.25]]
# 2045 =[[7212.25]]
# 2046 =[[7255.25]]
# 2047 =[[7298.25]]
# 2048 =[[7341.25]]
# 2049 =[[7384.25]]

# %%
df = pd.read_csv('Newtown.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Newtown',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('newtown_predict.csv')
# Out:
# 2020 =[[10920.25]]
# 2021 =[[11022.33333333]]
# 2022 =[[11124.41666667]]
# 2023 =[[11226.5]]
# 2024 =[[11328.58333333]]
# 2025 =[[11430.66666667]]
# 2026 =[[11532.75]]
# 2027 =[[11634.83333333]]
# 2028 =[[11736.91666667]]
# 2029 =[[11839.]]
# 2030 =[[11941.08333333]]
# 2031 =[[12043.16666667]]
# 2032 =[[12145.25]]
# 2033 =[[12247.33333333]]
# 2034 =[[12349.41666667]]
# 2035 =[[12451.5]]
# 2036 =[[12553.58333333]]
# 2037 =[[12655.66666667]]
# 2038 =[[12757.75]]
# 2039 =[[12859.83333333]]
# 2040 =[[12961.91666667]]
# 2041 =[[13064.]]
# 2042 =[[13166.08333333]]
# 2043 =[[13268.16666667]]
# 2044 =[[13370.25]]
# 2045 =[[13472.33333333]]
# 2046 =[[13574.41666667]]
# 2047 =[[13676.5]]
# 2048 =[[13778.58333333]]
# 2049 =[[13880.66666667]]

# %%
df = pd.read_csv('Norlane.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Norlane',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('Norlane_predict.csv')
# Out:
# 2020 =[[9111.71428571]]
# 2021 =[[9177.17857143]]
# 2022 =[[9242.64285714]]
# 2023 =[[9308.10714286]]
# 2024 =[[9373.57142857]]
# 2025 =[[9439.03571429]]
# 2026 =[[9504.5]]
# 2027 =[[9569.96428571]]
# 2028 =[[9635.42857143]]
# 2029 =[[9700.89285714]]
# 2030 =[[9766.35714286]]
# 2031 =[[9831.82142857]]
# 2032 =[[9897.28571429]]
# 2033 =[[9962.75]]
# 2034 =[[10028.21428571]]
# 2035 =[[10093.67857143]]
# 2036 =[[10159.14285714]]
# 2037 =[[10224.60714286]]
# 2038 =[[10290.07142857]]
# 2039 =[[10355.53571429]]
# 2040 =[[10421.]]
# 2041 =[[10486.46428571]]
# 2042 =[[10551.92857143]]
# 2043 =[[10617.39285714]]
# 2044 =[[10682.85714286]]
# 2045 =[[10748.32142857]]
# 2046 =[[10813.78571429]]
# 2047 =[[10879.25]]
# 2048 =[[10944.71428571]]
# 2049 =[[11010.17857143]]

# %%
df = pd.read_csv('North Geelong.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'North Geelong',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('northgeelong_predict.csv')
# Out:
# 2020 =[[4339.17857143]]
# 2021 =[[4447.85714286]]
# 2022 =[[4556.53571429]]
# 2023 =[[4665.21428571]]
# 2024 =[[4773.89285714]]
# 2025 =[[4882.57142857]]
# 2026 =[[4991.25]]
# 2027 =[[5099.92857143]]
# 2028 =[[5208.60714286]]
# 2029 =[[5317.28571429]]
# 2030 =[[5425.96428571]]
# 2031 =[[5534.64285714]]
# 2032 =[[5643.32142857]]
# 2033 =[[5752.]]
# 2034 =[[5860.67857143]]
# 2035 =[[5969.35714286]]
# 2036 =[[6078.03571429]]
# 2037 =[[6186.71428571]]
# 2038 =[[6295.39285714]]
# 2039 =[[6404.07142857]]
# 2040 =[[6512.75]]
# 2041 =[[6621.42857143]]
# 2042 =[[6730.10714286]]
# 2043 =[[6838.78571429]]
# 2044 =[[6947.46428571]]
# 2045 =[[7056.14285714]]
# 2046 =[[7164.82142857]]
# 2047 =[[7273.5]]
# 2048 =[[7382.17857143]]
# 2049 =[[7490.85714286]]

# %%
df = pd.read_csv('Ocean Grove.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Ocean Grove',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('oceangrove_predict.csv')
# Out:
# 2020 =[[16766.10714286]]
# 2021 =[[17273.79761905]]
# 2022 =[[17781.48809524]]
# 2023 =[[18289.17857143]]
# 2024 =[[18796.86904762]]
# 2025 =[[19304.55952381]]
# 2026 =[[19812.25]]
# 2027 =[[20319.94047619]]
# 2028 =[[20827.63095238]]
# 2029 =[[21335.32142857]]
# 2030 =[[21843.01190476]]
# 2031 =[[22350.70238095]]
# 2032 =[[22858.39285714]]
# 2033 =[[23366.08333333]]
# 2034 =[[23873.77380952]]
# 2035 =[[24381.46428571]]
# 2036 =[[24889.1547619]]
# 2037 =[[25396.8452381]]
# 2038 =[[25904.53571429]]
# 2039 =[[26412.22619048]]
# 2040 =[[26919.91666667]]
# 2041 =[[27427.60714286]]
# 2042 =[[27935.29761905]]
# 2043 =[[28442.98809524]]
# 2044 =[[28950.67857143]]
# 2045 =[[29458.36904762]]
# 2046 =[[29966.05952381]]
# 2047 =[[30473.75]]
# 2048 =[[30981.44047619]]
# 2049 =[[31489.13095238]]

# %%
df = pd.read_csv('Portarlington.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Portarlington',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('portarlington_predict.csv')
# Out:
# 2020 =[[3999.57142857]]
# 2021 =[[4068.05952381]]
# 2022 =[[4136.54761905]]
# 2023 =[[4205.03571429]]
# 2024 =[[4273.52380952]]
# 2025 =[[4342.01190476]]
# 2026 =[[4410.5]]
# 2027 =[[4478.98809524]]
# 2028 =[[4547.47619048]]
# 2029 =[[4615.96428571]]
# 2030 =[[4684.45238095]]
# 2031 =[[4752.94047619]]
# 2032 =[[4821.42857143]]
# 2033 =[[4889.91666667]]
# 2034 =[[4958.4047619]]
# 2035 =[[5026.89285714]]
# 2036 =[[5095.38095238]]
# 2037 =[[5163.86904762]]
# 2038 =[[5232.35714286]]
# 2039 =[[5300.8452381]]
# 2040 =[[5369.33333333]]
# 2041 =[[5437.82142857]]
# 2042 =[[5506.30952381]]
# 2043 =[[5574.79761905]]
# 2044 =[[5643.28571429]]
# 2045 =[[5711.77380952]]
# 2046 =[[5780.26190476]]
# 2047 =[[5848.75]]
# 2048 =[[5917.23809524]]
# 2049 =[[5985.72619048]]

# %%
df = pd.read_csv('Rural Bellarine Peninsula.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Rural Bellarine Peninsula',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('RuralBellarinePeninsula_predict.csv')
# Out:
# 2020 =[[3341.78571429]]
# 2021 =[[3452.4047619]]
# 2022 =[[3563.02380952]]
# 2023 =[[3673.64285714]]
# 2024 =[[3784.26190476]]
# 2025 =[[3894.88095238]]
# 2026 =[[4005.5]]
# 2027 =[[4116.11904762]]
# 2028 =[[4226.73809524]]
# 2029 =[[4337.35714286]]
# 2030 =[[4447.97619048]]
# 2031 =[[4558.5952381]]
# 2032 =[[4669.21428571]]
# 2033 =[[4779.83333333]]
# 2034 =[[4890.45238095]]
# 2035 =[[5001.07142857]]
# 2036 =[[5111.69047619]]
# 2037 =[[5222.30952381]]
# 2038 =[[5332.92857143]]
# 2039 =[[5443.54761905]]
# 2040 =[[5554.16666667]]
# 2041 =[[5664.78571429]]
# 2042 =[[5775.4047619]]
# 2043 =[[5886.02380952]]
# 2044 =[[5996.64285714]]
# 2045 =[[6107.26190476]]
# 2046 =[[6217.88095238]]
# 2047 =[[6328.5]]
# 2048 =[[6439.11904762]]
# 2049 =[[6549.73809524]]

# %%
df = pd.read_csv('Rural North.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Rural North',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('Ruralnorth_predict.csv')
# Out:
# 2020 =[[1992.71428571]]
# 2021 =[[2036.51190476]]
# 2022 =[[2080.30952381]]
# 2023 =[[2124.10714286]]
# 2024 =[[2167.9047619]]
# 2025 =[[2211.70238095]]
# 2026 =[[2255.5]]
# 2027 =[[2299.29761905]]
# 2028 =[[2343.0952381]]
# 2029 =[[2386.89285714]]
# 2030 =[[2430.69047619]]
# 2031 =[[2474.48809524]]
# 2032 =[[2518.28571429]]
# 2033 =[[2562.08333333]]
# 2034 =[[2605.88095238]]
# 2035 =[[2649.67857143]]
# 2036 =[[2693.47619048]]
# 2037 =[[2737.27380952]]
# 2038 =[[2781.07142857]]
# 2039 =[[2824.86904762]]
# 2040 =[[2868.66666667]]
# 2041 =[[2912.46428571]]
# 2042 =[[2956.26190476]]
# 2043 =[[3000.05952381]]
# 2044 =[[3043.85714286]]
# 2045 =[[3087.6547619]]
# 2046 =[[3131.45238095]]
# 2047 =[[3175.25]]
# 2048 =[[3219.04761905]]
# 2049 =[[3262.8452381]]

# %%
df = pd.read_csv('South Geelong.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'South Geelong',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('southgeelong_predict.csv')
# Out:
# 2020 =[[3846.35714286]]
# 2021 =[[3872.21428571]]
# 2022 =[[3898.07142857]]
# 2023 =[[3923.92857143]]
# 2024 =[[3949.78571429]]
# 2025 =[[3975.64285714]]
# 2026 =[[4001.5]]
# 2027 =[[4027.35714286]]
# 2028 =[[4053.21428571]]
# 2029 =[[4079.07142857]]
# 2030 =[[4104.92857143]]
# 2031 =[[4130.78571429]]
# 2032 =[[4156.64285714]]
# 2033 =[[4182.5]]
# 2034 =[[4208.35714286]]
# 2035 =[[4234.21428571]]
# 2036 =[[4260.07142857]]
# 2037 =[[4285.92857143]]
# 2038 =[[4311.78571429]]
# 2039 =[[4337.64285714]]
# 2040 =[[4363.5]]
# 2041 =[[4389.35714286]]
# 2042 =[[4415.21428571]]
# 2043 =[[4441.07142857]]
# 2044 =[[4466.92857143]]
# 2045 =[[4492.78571429]]
# 2046 =[[4518.64285714]]
# 2047 =[[4544.5]]
# 2048 =[[4570.35714286]]
# 2049 =[[4596.21428571]]

# %%
df = pd.read_csv('St Albans Park.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'St Albans Park',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('StAlbansPark_predict.csv')
# Out:
# 2020 =[[4985.78571429]]
# 2021 =[[4992.48809524]]
# 2022 =[[4999.19047619]]
# 2023 =[[5005.89285714]]
# 2024 =[[5012.5952381]]
# 2025 =[[5019.29761905]]
# 2026 =[[5026.]]
# 2027 =[[5032.70238095]]
# 2028 =[[5039.4047619]]
# 2029 =[[5046.10714286]]
# 2030 =[[5052.80952381]]
# 2031 =[[5059.51190476]]
# 2032 =[[5066.21428571]]
# 2033 =[[5072.91666667]]
# 2034 =[[5079.61904762]]
# 2035 =[[5086.32142857]]
# 2036 =[[5093.02380952]]
# 2037 =[[5099.72619048]]
# 2038 =[[5106.42857143]]
# 2039 =[[5113.13095238]]
# 2040 =[[5119.83333333]]
# 2041 =[[5126.53571429]]
# 2042 =[[5133.23809524]]
# 2043 =[[5139.94047619]]
# 2044 =[[5146.64285714]]
# 2045 =[[5153.3452381]]
# 2046 =[[5160.04761905]]
# 2047 =[[5166.75]]
# 2048 =[[5173.45238095]]
# 2049 =[[5180.1547619]]

# %%
df = pd.read_csv('St Leonards.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'St Leonards',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('StLeonards_predict.csv')
# Out:
# 2020 =[[4079.67857143]]
# 2021 =[[4185.44047619]]
# 2022 =[[4291.20238095]]
# 2023 =[[4396.96428571]]
# 2024 =[[4502.72619048]]
# 2025 =[[4608.48809524]]
# 2026 =[[4714.25]]
# 2027 =[[4820.01190476]]
# 2028 =[[4925.77380952]]
# 2029 =[[5031.53571429]]
# 2030 =[[5137.29761905]]
# 2031 =[[5243.05952381]]
# 2032 =[[5348.82142857]]
# 2033 =[[5454.58333333]]
# 2034 =[[5560.3452381]]
# 2035 =[[5666.10714286]]
# 2036 =[[5771.86904762]]
# 2037 =[[5877.63095238]]
# 2038 =[[5983.39285714]]
# 2039 =[[6089.1547619]]
# 2040 =[[6194.91666667]]
# 2041 =[[6300.67857143]]
# 2042 =[[6406.44047619]]
# 2043 =[[6512.20238095]]
# 2044 =[[6617.96428571]]
# 2045 =[[6723.72619048]]
# 2046 =[[6829.48809524]]
# 2047 =[[6935.25]]
# 2048 =[[7041.01190476]]
# 2049 =[[7146.77380952]]

# %%
df = pd.read_csv('Warun Ponds.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Warun ponds',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('warunponds_predict.csv')
# Out:
# 2020 =[[6200.71428571]]
# 2021 =[[6421.0952381]]
# 2022 =[[6641.47619048]]
# 2023 =[[6861.85714286]]
# 2024 =[[7082.23809524]]
# 2025 =[[7302.61904762]]
# 2026 =[[7523.]]
# 2027 =[[7743.38095238]]
# 2028 =[[7963.76190476]]
# 2029 =[[8184.14285714]]
# 2030 =[[8404.52380952]]
# 2031 =[[8624.9047619]]
# 2032 =[[8845.28571429]]
# 2033 =[[9065.66666667]]
# 2034 =[[9286.04761905]]
# 2035 =[[9506.42857143]]
# 2036 =[[9726.80952381]]
# 2037 =[[9947.19047619]]
# 2038 =[[10167.57142857]]
# 2039 =[[10387.95238095]]
# 2040 =[[10608.33333333]]
# 2041 =[[10828.71428571]]
# 2042 =[[11049.0952381]]
# 2043 =[[11269.47619048]]
# 2044 =[[11489.85714286]]
# 2045 =[[11710.23809524]]
# 2046 =[[11930.61904762]]
# 2047 =[[12151.]]
# 2048 =[[12371.38095238]]
# 2049 =[[12591.76190476]]

# %%
df = pd.read_csv('Whittingtons.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Whittingtons',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('Whittingtons_predict.csv')
# Out:
# 2020 =[[3879.03571429]]
# 2021 =[[3852.1547619]]
# 2022 =[[3825.27380952]]
# 2023 =[[3798.39285714]]
# 2024 =[[3771.51190476]]
# 2025 =[[3744.63095238]]
# 2026 =[[3717.75]]
# 2027 =[[3690.86904762]]
# 2028 =[[3663.98809524]]
# 2029 =[[3637.10714286]]
# 2030 =[[3610.22619048]]
# 2031 =[[3583.3452381]]
# 2032 =[[3556.46428571]]
# 2033 =[[3529.58333333]]
# 2034 =[[3502.70238095]]
# 2035 =[[3475.82142857]]
# 2036 =[[3448.94047619]]
# 2037 =[[3422.05952381]]
# 2038 =[[3395.17857143]]
# 2039 =[[3368.29761905]]
# 2040 =[[3341.41666667]]
# 2041 =[[3314.53571429]]
# 2042 =[[3287.6547619]]
# 2043 =[[3260.77380952]]
# 2044 =[[3233.89285714]]
# 2045 =[[3207.01190476]]
# 2046 =[[3180.13095238]]
# 2047 =[[3153.25]]
# 2048 =[[3126.36904762]]
# 2049 =[[3099.48809524]]

# %%
df = pd.read_csv('Barwon Heads.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Barwon Heads',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('barwonheads_predict.csv')
# Out:
# 2020 =[[5266.10714286]]
# 2021 =[[5411.88095238]]
# 2022 =[[5557.6547619]]
# 2023 =[[5703.42857143]]
# 2024 =[[5849.20238095]]
# 2025 =[[5994.97619048]]
# 2026 =[[6140.75]]
# 2027 =[[6286.52380952]]
# 2028 =[[6432.29761905]]
# 2029 =[[6578.07142857]]
# 2030 =[[6723.8452381]]
# 2031 =[[6869.61904762]]
# 2032 =[[7015.39285714]]
# 2033 =[[7161.16666667]]
# 2034 =[[7306.94047619]]
# 2035 =[[7452.71428571]]
# 2036 =[[7598.48809524]]
# 2037 =[[7744.26190476]]
# 2038 =[[7890.03571429]]
# 2039 =[[8035.80952381]]
# 2040 =[[8181.58333333]]
# 2041 =[[8327.35714286]]
# 2042 =[[8473.13095238]]
# 2043 =[[8618.9047619]]
# 2044 =[[8764.67857143]]
# 2045 =[[8910.45238095]]
# 2046 =[[9056.22619048]]
# 2047 =[[9202.]]
# 2048 =[[9347.77380952]]
# 2049 =[[9493.54761905]]

# %%
df = pd.read_csv('Armstrong Creek.csv',thousands=',')
df.head(8)
x = df.iloc[0:8, 1].values.reshape(-1, 1)
y = df.iloc[0:8, 2].values.reshape(-1, 1)
#y
model = LinearRegression().fit(x, y)
y_pred = model.predict([[2020]])
y_pred
for i in range(2020,2050):
    y_pred=model.predict([[i]])
    print(i,"={}".format(y_pred))
    df = df.append({"Suburb": 'Armstrong Creek',"Year" : i,"Population" : y_pred}, ignore_index = True)
df.to_csv('Armstrongcreek_predict.csv')
# Out:
# 2020 =[[10785.10714286]]
# 2021 =[[11985.21428571]]
# 2022 =[[13185.32142857]]
# 2023 =[[14385.42857143]]
# 2024 =[[15585.53571429]]
# 2025 =[[16785.64285714]]
# 2026 =[[17985.75]]
# 2027 =[[19185.85714286]]
# 2028 =[[20385.96428571]]
# 2029 =[[21586.07142857]]
# 2030 =[[22786.17857143]]
# 2031 =[[23986.28571429]]
# 2032 =[[25186.39285714]]
# 2033 =[[26386.5]]
# 2034 =[[27586.60714286]]
# 2035 =[[28786.71428571]]
# 2036 =[[29986.82142857]]
# 2037 =[[31186.92857143]]
# 2038 =[[32387.03571429]]
# 2039 =[[33587.14285714]]
# 2040 =[[34787.25]]
# 2041 =[[35987.35714286]]
# 2042 =[[37187.46428571]]
# 2043 =[[38387.57142857]]
# 2044 =[[39587.67857143]]
# 2045 =[[40787.78571429]]
# 2046 =[[41987.89285714]]
# 2047 =[[43188.]]
# 2048 =[[44388.10714286]]
# 2049 =[[45588.21428571]]
